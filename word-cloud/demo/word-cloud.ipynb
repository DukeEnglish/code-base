# %%
# https://www.jianshu.com/p/721190534061

filename = "test_text.txt"
with open(filename) as f:
    mytext = f.read()
import jieba
mytext = " ".join(jieba.cut(mytext))

from wordcloud import WordCloud
wordcloud = WordCloud().generate(mytext)

# %pylab inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/b7/t4jynbgx15l4n6vhy95bl47m0000gn/T/jieba.cache
# Loading model cost 0.788 seconds.
# Prefix dict has been built succesfully.
# /Users/lijunyi/anaconda3/envs/xgb/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# Populating the interactive namespace from numpy and matplotlib
# (-0.5, 399.5, 199.5, -0.5)

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(font_path="/Users/lijunyi/Self_improvement/Study/NLP/font/simsun.ttf").generate(mytext)
# %pylab inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-0.5, 399.5, 199.5, -0.5)
